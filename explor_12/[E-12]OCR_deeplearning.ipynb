# %% [markdown]
# ## 문자를 읽을 수 있는 딥러닝

# %% [markdown]
# ### [ 목   차 ]
# <br>
# STEP1. 검증용 데이터셋 준비
#
# STEP2. keras-ocr, Tesseract로 테스트 진행(Google OCT API 선택사항)
#
# STEP3. 테스트 결과 정리
#
# STEP4. 결과분석과 결론제시
#
# [ 회 고 ]

# %%
# %%capture
# !pip install keras-ocr

# %%
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
from glob import glob

# %% [markdown]
# #### STEP1. 검증용 데이터셋 준비
#    * 다양한 수학책의 표지 이미지 20장 준비
#    * 배경 무늬 다양하게 선정
#    * 문자 기울어진 것, 세로방향 포함, 많은 텍스트 포함된 표지 등 준비

# %%
images = sorted(glob('/content/drive/MyDrive/LMS/E_12/images/*.png'))
image_names = [x.split("/")[-1] for x in images]
image_names
# Out:
# ['img_01.png',
#  'img_02.png',
#  'img_03.png',
#  'img_04.png',
#  'img_05.png',
#  'img_06.png',
#  'img_07.png',
#  'img_08.png',
#  'img_09.png',
#  'img_10.png',
#  'img_11.png',
#  'img_12.png',
#  'img_13.png',
#  'img_14.png',
#  'img_15.png',
#  'img_16.png',
#  'img_17.png',
#  'img_18.png',
#  'img_19.png',
#  'img_20.png']

# %%
# 인식에 사용할 이미지 20장 확인
plt.figure(figsize=(18, 24))

for i, (img, name) in tqdm(enumerate(zip(images, image_names))):
    plt.subplot(5, 4, i+1)
    plt.title(f'{name}')

    img_bgr = cv2.imread(img)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    
    plt.gca().get_xaxis().set_visible(False)
    plt.gca().get_yaxis().set_visible(False)

    plt.tight_layout()

plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### STEP2. 테스트 진행
#   * keras-ocr, Tesseract로 테스트
#   * (Google ocr api는 선택사항)

# %% [markdown]
# ### keras_ocr

# %%
import keras_ocr

# keras-ocr이 detector과 recognizer를 위한 모델을 자동으로 다운로드받게 됩니다. 
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Downloading /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# Downloading /root/.keras-ocr/crnn_kurapan.h5

# %%
# 14분 44초

keras_images = [ keras_ocr.tools.read(img) for img in images ]
prediction_groups = [pipeline.recognize([img]) for img in tqdm(images)]
# Out:
# 100%|██████████| 20/20 [09:19<00:00, 27.99s/it]

# %%
def draw_keras_ocr(images, prediction_groups):
  # Plot the predictions
  fig, axs = plt.subplots(nrows=len(images), figsize=(8, 80))
  fig.tight_layout()
  for idx, ax in enumerate(axs):
      keras_ocr.tools.drawAnnotations(image=images[idx], 
                                      predictions=prediction_groups[idx][0], ax=ax)

# %%
draw_keras_ocr(keras_images, prediction_groups)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# prediction_groups 내용 확인: 인식한 텍스트 및 이미지 위치 정보

print(type(prediction_groups))
print(prediction_groups[0][0][0])
print(prediction_groups[0][0][0][0])
print(prediction_groups[0][0][0][1])
# Out:
# <class 'list'>
# ('pearson', array([[176., 284.],
#        [279., 284.],
#        [279., 303.],
#        [176., 303.]], dtype=float32))
# pearson
# [[176. 284.]
#  [279. 284.]
#  [279. 303.]
#  [176. 303.]]

# %%
# keras_ocr 가 인식한 텍스트
keras_ocr_dict = {}
keras_ocr_text_list = []

for idx, img in enumerate(images):
  keras_ocr_dict[img] = prediction_groups[idx][0]
  keras_ocr_text_list.append([idx, list(zip(*keras_ocr_dict[img]))[0]])

# %%
# keras_ocr 이 인식한 문자 리스트

keras_ocr_text_list
# Out:
# [[0,
#   ('pearson',
#    'new',
#    'international',
#    'edition',
#    'algebra',
#    'michael',
#    'artin',
#    'second',
#    'edition',
#    'pearson',
#    'always',
#    'learning')],
#  [1,
#   ('first',
#    'course',
#    'a',
#    'in',
#    'differential',
#    'equations',
#    'modeling',
#    'with',
#    'applications',
#    '11e')],
#  [2, ('first', 'course', 'a', 'in', 'probability', 'tenth', 'edition')],
#  [3, ('abstract', 'algebra', 'a', 'first', 'course', 'second', 'edition')],
#  [4,
#   ('andabpled',
#    'pure',
#    'sall',
#    '5',
#    'the',
#    'undergraduate',
#    'texts',
#    '5',
#    'series',
#    '',
#    'advanced',
#    'calculus',
#    'intended',
#    'for',
#    'furnish',
#    'thie',
#    'back',
#    'is',
#    'text',
#    'that',
#    'as',
#    'a',
#    'courses',
#    'bone',
#    'of',
#    'the',
#    'students',
#    'undergraduate',
#    'educat',
#    'tion',
#    'in',
#    'mathematical',
#    'analysis',
#    'the',
#    'goal',
#    'is',
#    'rigorously',
#    'the',
#    'fundamental',
#    'within',
#    'the',
#    'of',
#    'to',
#    'present',
#    'context',
#    'concepts',
#    'self',
#    'illuminating',
#    'examples',
#    'and',
#    'stimulating',
#    'exercises',
#    'this',
#    'book',
#    'contained',
#    'advanced',
#    'is',
#    'and',
#    'with',
#    'the',
#    'creation',
#    'of',
#    'basic',
#    'tools',
#    'using',
#    'the',
#    'completeness',
#    'starts',
#    'axiom',
#    'diferentiability',
#    'integrability',
#    'the',
#    'continuity',
#    'and',
#    'series',
#    'representa',
#    'power',
#    'calculus',
#    'tion',
#    'properties',
#    'of',
#    'functions',
#    'of',
#    'single',
#    'variable',
#    'established',
#    'the',
#    'next',
#    '',
#    'a',
#    'are',
#    'describe',
#    'few',
#    'chapters',
#    'the',
#    'topological',
#    'and',
#    'metric',
#    'properties',
#    'of',
#    'euclidean',
#    'basis',
#    'of',
#    'these',
#    'the',
#    'of',
#    'treatment',
#    'diferential',
#    'calculus',
#    'space',
#    'are',
#    'rigorous',
#    'a',
#    'lincluding',
#    'implicit',
#    'multipliersl',
#    'the',
#    'function',
#    'lheorem',
#    'and',
#    'lagrange',
#    'for',
#    'second',
#    'edition',
#    'between',
#    'euclidean',
#    'for',
#    'functions',
#    'of',
#    'mappings',
#    'and',
#    'integration',
#    'several',
#    'spaces',
#    'variables',
#    'real',
#    'special',
#    'has',
#    'been',
#    'paid',
#    'for',
#    'selected',
#    'attention',
#    'to',
#    'the',
#    'motivation',
#    'proofs',
#    'topics',
#    '',
#    'such',
#    'the',
#    'picard',
#    'existence',
#    'theorem',
#    'for',
#    'differential',
#    'have',
#    'equations',
#    'been',
#    'as',
#    'included',
#    'in',
#    'such',
#    'that',
#    'selections',
#    'be',
#    'made',
#    'while',
#    'fluid',
#    'preserving',
#    'a',
#    'way',
#    'may',
#    'd',
#    'presentation',
#    'of',
#    'the',
#    'essential',
#    'material',
#    'patrick',
#    'ml',
#    'fitzpatrick',
#    '',
#    'supplemented',
#    'with',
#    'exercisess',
#    'advanced',
#    'calculus',
#    'perfect',
#    'is',
#    'numerous',
#    'a',
#    'book',
#    'for',
#    'undergra',
#    'duate',
#    'students',
#    'of',
#    'analysis',
#    's',
#    'isen',
#    '4t0',
#    'o',
#    '8210',
#    '1791',
#    'for',
#    'additional',
#    'information',
#    'and',
#    'updates',
#    'books',
#    'this',
#    'visit',
#    'on',
#    'camsogboagesastets',
#    'www',
#    'ams',
#    'the',
#    'web',
#    'om',
#    '9',
#    '76082',
#    '817916',
#    'wwwamsorg',
#    'amistexts',
#    'this',
#    'series',
#    'founded',
#    'by',
#    'che',
#    'highly',
#    'respected',
#    'was',
#    'society',
#    'american',
#    'mathematical',
#    'mathematician',
#    'and',
#    'educator',
#    'paul',
#    'sally',
#    'h',
#    'jr')],
#  [5,
#   ('introduction',
#    'an',
#    'to',
#    'mathematics',
#    'abstract',
#    'robert',
#    'bond',
#    'ja',
#    'william',
#    'keane',
#    'j')],
#  [6,
#   ('texts',
#    'and',
#    'readings',
#    'trim',
#    '37',
#    'mathematics',
#    'in',
#    'e',
#    'l',
#    'analysis',
#    's',
#    'terence',
#    'tao',
#    'se',
#    'qa',
#    '300',
#    't325',
#    '2000',
#    'val',
#    'hindustan',
#    'ho',
#    'agency',
#    'book',
#    'l',
#    'lun',
#    'l')],
#  [7,
#   ('e',
#    'e',
#    'edition',
#    'sixth',
#    'applied',
#    'combinatorics',
#    'alan',
#    'tucker')],
#  [8, ('calculus', 'edition', 'fourth', 'spivak', 'michael')],
#  [9,
#   ('james',
#    'stewart',
#    'calculus',
#    'eighth',
#    'edition',
#    'early',
#    'transcendentals')],
#  [10, ('calcises', 'made', 'easy', 'themeson', 'macmiltan')],
#  [11,
#   ('ninth',
#    'edition',
#    'complex',
#    'variables',
#    'applications',
#    'and',
#    'zaxtiy',
#    'd',
#    'x',
#    'ward',
#    'brown',
#    'james',
#    'ruel',
#    'churchill',
#    'va')],
#  [12,
#   ('gallian',
#    'joseph',
#    'a',
#    'contemporary',
#    'abstract',
#    'algebra',
#    'ninth',
#    'edition')],
#  [13,
#   ('i',
#    'discrete',
#    'mathematical',
#    'structures',
#    'sixth',
#    'edition',
#    'kolman',
#    'busby',
#    'ross')],
#  [14,
#   ('cengage',
#    'discrete',
#    'mathematics',
#    'applications',
#    'with',
#    'fifth',
#    'edition',
#    'susanna',
#    's',
#    'epp')],
#  [15,
#   ('undergraduate',
#    'texts',
#    'mathematics',
#    'in',
#    'utm',
#    'kenneth',
#    'ross',
#    'a',
#    'elementary',
#    'analysis',
#    'of',
#    'the',
#    'theory',
#    'calculus',
#    'edition',
#    'second',
#    'e1',
#    'ed')],
#  [16,
#   ('11th',
#    'edition',
#    'nl',
#    'lnea',
#    'age',
#    'anton',
#    'chris',
#    'howard',
#    'rorres',
#    'wiley',
#    'applications',
#    'version')],
#  [17,
#   ('elementary',
#    'tenth',
#    'edition',
#    'linear',
#    'algebra',
#    'version',
#    'applications')],
#  [18,
#   ('oreilly',
#    'essential',
#    'math',
#    'science',
#    'data',
#    'for',
#    'of',
#    'fundamental',
#    'take',
#    'control',
#    'your',
#    'with',
#    'data',
#    'calculus',
#    'probability',
#    'linear',
#    'algebra',
#    'statistics',
#    '8',
#    'early',
#    'release',
#    'raw',
#    's',
#    'unedited',
#    'hadrien',
#    'jean')],
#  [19,
#   ('finitedimensional',
#    'vector',
#    'spaces',
#    'second',
#    'edition',
#    'paul',
#    'halmos',
#    'r')]]

# %% [markdown]
# ### tesseract-ocr

# %%
# %%capture
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

# %%
# %%capture
# !pip install pytesseract

# %%
import os
import pytesseract
from PIL import Image
from pytesseract import Output
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# OCR Engine modes(–oem):
# 0 - Legacy engine only.
# 1 - Neural nets LSTM engine only.
# 2 - Legacy + LSTM engines.
# 3 - Default, based on what is available.

# Page segmentation modes(–psm):
# 0 - Orientation and script detection (OSD) only.
# 1 - Automatic page segmentation with OSD.
# 2 - Automatic page segmentation, but no OSD, or OCR.
# 3 - Fully automatic page segmentation, but no OSD. (Default)
# 4 - Assume a single column of text of variable sizes.
# 5 - Assume a single uniform block of vertically aligned text.
# 6 - Assume a single uniform block of text.
# 7 - Treat the image as a single text line.
# 8 - Treat the image as a single word.
# 9 - Treat the image as a single word in a circle.
# 10 - Treat the image as a single character.
# 11 - Sparse text. Find as much text as possible in no particular order.
# 12 - Sparse text with OSD.
# 13 - Raw line. Treat the image as a single text line, bypassing hacks that are Tesseract-specific.

def crop_word_regions(image_path='./images/sample.png', output_path='./output'):
    if not os.path.exists(output_path):
        os.mkdir(output_path)
    custom_oem_psm_config = r'--oem 3 --psm 3'
    image = Image.open(image_path)

    recognized_data = pytesseract.image_to_data(
        image, lang='eng',    # 한국어라면 lang='kor'
        config=custom_oem_psm_config,
        output_type=Output.DICT
    )
    
    top_level = max(recognized_data['level'])
    index = 0
    cropped_image_dict = {}
    for i in range(len(recognized_data['level'])):
        level = recognized_data['level'][i]
    
        if level == top_level:
            left = recognized_data['left'][i]
            top = recognized_data['top'][i]
            width = recognized_data['width'][i]
            height = recognized_data['height'][i]
            
         #   img_file = images.split[index]('/')[-1][:-4]
            output_img_path = os.path.join(output_path, f"{str(index).zfill(4)}.png")
            print(output_img_path)
            cropped_image = image.crop((
                left,
                top,
                left+width,
                top+height
            ))
            cropped_image.save(output_img_path)
            cropped_image_dict[output_img_path] = [(left, top), (left+width, top), (left+width, top+height), (left, top+height)]
            index += 1
    return cropped_image_dict

# %%
def recognize_images(cropped_image_path_list):
    custom_oem_psm_config = r'--oem 3 --psm 7'
    
    text_list = []
    for image_path in cropped_image_path_list:
        image = Image.open(image_path)
        recognized_data = pytesseract.image_to_string(
            image, lang='eng',    # 한국어라면 lang='kor'
            config=custom_oem_psm_config,
            output_type=Output.DICT
        )
        text = recognized_data['text']
        print(text)
        text_list.append(text)
    print("Done")

    return text_list

# %%
# !pip install Pillow==9.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pillow==9.0.0
#   Downloading Pillow-9.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 7.4 MB/s
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.1.1
#     Uninstalling Pillow-9.1.1:
#       Successfully uninstalled Pillow-9.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-9.0.0

# %%
work_dir = '/content/drive/MyDrive/LMS/E_12/images'
output_dir = work_dir + '/tesseract_output'

tesseract_ocr_dict = {}
for img_path, img_file in zip(images, image_names):
    print(f'---------------{img_file}---------------')
    cropped_image_dict = crop_word_regions(img_path, output_dir)
    
    # 위에서 준비한 문자 영역 파일들을 인식하여 얻어진 텍스트를 출력합니다.
    text_list = recognize_images(cropped_image_dict.keys())
    tesseract_ocr_dict[img_file] = {'text_list': text_list, 'cropped_image_dict': cropped_image_dict}
# Out:
# ---------------img_01.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# PEARSON
#
# NEW
#
# INTERNAT.
#
# | EDITION
#
# Algebra
#
# Vichael
#
# Artin
#
# Secon
#
# d Edition
#
# AYS LEARWNIWN
#
# ce
#
# PEARSON
#
# Done
# ---------------img_02.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0014.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0015.png
# i ae
#
# A First
#
# Cour
#
# ma
#
# DSS Ne
#
# FOUATIONS
#
# with
#
# Modeling
#
# Applications
#
# ‘a
#
# >.
#
# ae
#
# a
#
# s
#
# 3 i
#
#
# Done
# ---------------img_03.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# A
#
# Hirst
#
# (Course
#
# in
#
# Probability
#
# . i r . 1 ,
#
#
# Done
# ---------------img_04.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0014.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0015.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0016.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0017.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0018.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0019.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0020.png
# =|
#
# ABSTRACT
#
# 2S
#
# \
#
#
#
# A First
#
#
#
#
# af
#
# S
#
# ty ta eee
#
#
#
#
#
#
# nh
#
# =
#
# ff
#
# Done
# ---------------img_05.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0014.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0015.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0016.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0017.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0018.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0019.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0020.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0021.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0022.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0023.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0024.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0025.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0026.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0027.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0028.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0029.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0030.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0031.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0032.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0033.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0034.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0035.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0036.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0037.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0038.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0039.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0040.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0041.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0042.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0043.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0044.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0045.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0046.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0047.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0048.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0049.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0050.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0051.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0052.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0053.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0054.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0055.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0056.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0057.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0058.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0059.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0060.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0061.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0062.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0063.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0064.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0065.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0066.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0067.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0068.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0069.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0070.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0071.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0072.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0073.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0074.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0075.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0076.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0077.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0078.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0079.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0080.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0081.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0082.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0083.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0084.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0085.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0086.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0087.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0088.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0089.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0090.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0091.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0092.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0093.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0094.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0095.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0096.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0097.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0098.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0099.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0100.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0101.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0102.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0103.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0104.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0105.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0106.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0107.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0108.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0109.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0110.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0111.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0112.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0113.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0114.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0115.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0116.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0117.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0118.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0119.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0120.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0121.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0122.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0123.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0124.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0125.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0126.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0127.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0128.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0129.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0130.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0131.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0132.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0133.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0134.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0135.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0136.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0137.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0138.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0139.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0140.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0141.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0142.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0143.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0144.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0145.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0146.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0147.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0148.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0149.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0150.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0151.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0152.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0153.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0154.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0155.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0156.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0157.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0158.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0159.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0160.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0161.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0162.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0163.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0164.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0165.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0166.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0167.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0168.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0169.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0170.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0171.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0172.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0173.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0174.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0175.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0176.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0177.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0178.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0179.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0180.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0181.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0182.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0183.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0184.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0185.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0186.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0187.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0188.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0189.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0190.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0191.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0192.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0193.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0194.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0195.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0196.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0197.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0198.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0199.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0200.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0201.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0202.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0203.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0204.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0205.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0206.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0207.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0208.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0209.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0210.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0211.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0212.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0213.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0214.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0215.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0216.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0217.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0218.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0219.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0220.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0221.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0222.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0223.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0224.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0225.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0226.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0227.png
#
# Advanced
#
# ( aiculiu
#
# SS iS
#
# intended
#
# a
#
# a
#
# Text
#
# for
#
# Cott Aes.
#
# that
#
# furnish
#
# the
#
# hack-
#
# hon
#
# oof
#
# the
#
# student s
#
# undergraduate
#
# ecucation
#
# in
#
# mathematical
#
# analysis
#
# the
#
# be UO ch
#
# li
#
# Sto
#
# rigorously
#
# VICSecll
#
# t the
#
# fundamental
#
# concepts
#
# within
#
# the
#
# CoOnrext
#
# of
#
# iluminating
#
# examples
#
# and
#
# stimulating
#
# PYercises
#
# ‘This
#
# HOO!
#
# |
#
# s self-contained
#
# eT
#
# crarrs
#
# with
#
# the
#
# creation
#
# yf
#
# hacic
#
# roots
#
# using
#
# the
#
# completeness
#
# oe RTE RTT
#
# The
#
# continuity,
#
# differentiability,
#
# integrability,
#
# and
#
# power
#
# Series
#
# representa~
#
# riCory
#
# properties
#
# of
#
# huncrions
#
# oft
#
# “a
#
# single
#
# Variable
#
# are
#
# established.
#
# ‘The
#
# next
#
# few
#
# chapters
#
# describe
#
# the
#
# topological
#
# anc
#
# metric
#
# properties
#
# of
#
# EFuctidean
#
# Sale,
#
# These
#
# are
#
# the
#
# hasis
#
# of
#
# +
#
# PISOrous
#
# treatment
#
# ot
#
# differential
#
# ralcuins
#
# (including
#
# the
#
# Implicit
#
# rUONnCcTLON
#
# ‘Lheorem
#
# and
#
# Lagrange
#
# Multipliers)
#
# for
#
# RGD LL
#
# between
#
# ruciidean
#
# Valls
#
# and
#
# integration
#
# rT
#
# r functions
#
# (>)
#
# f several
#
# real
#
# variables.
#
# special
#
# attention
#
# has
#
# heen
#
# pai
#
# d to
#
# the
#
# motivation
#
# for
#
# proots.
#
# Selected
#
# topics,
#
# such
#
# i.
#
# the
#
# Picard
#
# Existence
#
# Theorem
#
# for
#
# ditferential
#
# equations,
#
# have
#
# been
#
# mnclude
#
# qin
#
# such
#
# =|
#
# way
#
# rha
#
# tr selections
#
# fay
#
# ry.
#
# made
#
# while
#
# preserving
#
# t
#
# Hericl
#
# presentation
#
# (}
#
# { the
#
# essential
#
# material
#
# Supplemented
#
# with
#
# PPL Tie TOUsS
#
# CACTCISOS,
#
# Advanced
#
# ( alciulis
#
# ic
#
# 7
#
# perfect
#
# DOOK
#
# for
#
# undergraduate
#
# students
#
# of
#
# analysis
#
# i TT
#
# LSaN
#
# 978-0-8218-4791-4
#
# ror
#
# adcitional
#
# intormation
#
# all
#
# d updates
#
# CT)
#
# this
#
# book,
#
# visit
#
# www.ams.org/bookpages/amstext-5
#
# 7" BUGB"2
#
# 13a fS 16
#
# 4 7
#
# AMS on the Web
#
# 4 7
#
# 4 7
#
# AMS TEATS
#
# AVY
#
# AITIS.OF
#
#
#
# Nearer
#
# ¥
#
#
# :
#
#
#
#
# .
#
#
# 0
#
# Advanced
#
# Calculus
#
# Second
#
# Edition
#
# Patrick
#
# ivi.
#
# Fitzpatrick
#
# The
#
# Americ
#
# 3788
#
# Mathe
#
# matical Society
#
#
# \
#
# y
#
# YN |
#
# Qu | (ii | (i) eects
#
# Done
# ---------------img_06.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# No
#
# Introduction
#
# ce
#
# Abstract
#
# Mathematics
#
# ee) re
#
# Robert
#
# iF
#
# Bond
#
# TRI
#
# iF
#
# Keane
#
# Done
# ---------------img_07.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0014.png
#
#
# Cs
#
# :
#
#
# | F i=.
#
# | &
#
# =
#
# Analysis
#
# I
#
# Terence
#
# Tao
#
# HINDUSTAN
#
# BOOK
#
# AGENCY
#
# Done
# ---------------img_08.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
#
# eeeeeeeeeeeeeeeeeeeeeeeeeeeeeese=ceeeeeEeeeeeEEeeeeeEEOE ee ee ee EE ——EEEEEEEEOE_—_—EEOE—E—E—E—E—E—E—E—E—EeEee_ eee e—n5nt8Vo
#
# a meen 66 I I Os is eee cccCtiw”*~*~*~*Ci OC | ne 0 ts elle, eee lO eel Cl ee lh | 6
#
# rr ee 000 ee I ee ee a ee ee ee ee ee ee a. 2 aa ee ee a ee ea aa ee ee eee ee ee rr lll
#
# ———— eee eee ee ee eee ee EEO EE eee amauumeeeeee ee
#
# APPLIED
#
# COMBINATORICS
#
# ALAN
#
# F\
#
#
# TUC
#
# (44%
#
# Done
# ---------------img_09.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# he
#
# CALCULUS
#
# Fourth
#
# Ree
#
# Michael
#
# Spivak
#
# Done
# ---------------img_10.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0014.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0015.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0016.png
#
#
#
# AM
#
# JAMES
#
# STEWART
#
# eer
#
# sl oe Del
#
# 1ON [}—————
#
# Early
#
# Transcenadadentals
#
#
#
#
# |
#
#
#
# Done
# ---------------img_11.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0014.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0015.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0016.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0017.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0018.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0019.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0020.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0021.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0022.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0023.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0024.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0025.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0026.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0027.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0028.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0029.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0030.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0031.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0032.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0033.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0034.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0035.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0036.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0037.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0038.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0039.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0040.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0041.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0042.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0043.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0044.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0045.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0046.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0047.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0048.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0049.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0050.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0051.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0052.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0053.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0054.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0055.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0056.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0057.png
# Es aS en i)
#
# a le i et
#
# a le i et
#
# PS ee LS a ee, ee
#
#
#
#
#
# ——— ia i a? le eee ee ee I i i a lll ec rec eelhlhlhl——”,mltéi(< etmt<“—s;s™~COCC”,CtCOCOC™S. t:CS—“‘™”*~—~—O”COCOSSC“( se Sm SC S—OC™”OTTCCSC“—SC~SC hh !hCC™Ct™t™””™”O~™~™~™~™~™O,- OCCD”:CUMlCle eee ee ee ee eee oe ss Le Ke ei tll eel ceeetst=<(<iati‘(‘i‘C (CairhShO!”!™~CO”CT!T:~C”C””~CCOCC”—C”~™”_.L..L.CDCLCLDDLmD—l—CdS”s:Cta“(”llllel a lee, eee ee eee
#
# iN am am II I tite I i A 6 i NN 6 Ii i ele lel lti‘( ‘ial lll CU eee, eee eee eee, ee ee ee eee eee
#
# iN am am II I tite I i A 6 i NN 6 Ii i ele lel lti‘( ‘ial lll CU eee, eee eee eee, ee ee ee eee eee
#
# a A a ey Oa a ee a BOT es SE are
#
# Oh a en nln OE a i Bc ig I a Oe a ae
#
# ee 2} an = OL oe ee et ee een, SO OG EF 7 ee ae 6 AS) _) TO ee - 4, OO  ’ ee te eee
#
#
# i a ae © a. wre ee SS oe as NR ee ane a ee eed ok Te | fe eh on he ee Pe gee a ey ee ee eee eS ee ll” lk Ble
#
# 6 Se ee ee i en ae SU i et | ee eee
#
# 6 Se ee ee i en ae SU i et | ee eee
#
# 6 Se ee ee i en ae SU i et | ee eee
#
# 6 Se ee ee i en ae SU i et | ee eee
#
# etl Ne A a i ns 0  —————
#
# tit a ete ee ee ee eee 2a 6 4 =e ®t OF OF Ee ie... ee Eee, ee ee th et ee tin mine 2 6 OL OK Te ee ee eee ar, .-.. . ee bees oc eee
#
# OO I OO ee Ee ee ”6—6Uu”|6hU6L?h ll | i i” eee eee rr ee ree ie ee ee ea eee a FE fF fFlUlc( ‘(OC ‘(‘C‘(C(<é‘é<‘(‘<‘(‘(‘( ll dasSOCO.h)hmDmDmWmWmDrDDrmUmUmUrme EE ECTSL EEE ee ee ee eee ee, ee
#
# a i, a cia, did, te i a Oa ee er ee ee ee ee Oe, es ct tke ce tt ee eee ees eee eee a een FF fthUlclUlClU Oe eS el NR oon «
#
# a mn ae Sri A NN el el ee ete Se a a Os ie Oe ee hidden> St
#
#
#
#
#
# SI, a a ee ee eS eS. SSS
#
# i NE ee en al et
#
# I a toting eee ee ne TE a Te Se ne een nn nye) a ~ hte 9 a Ee  — ee
#
# an na bat 6 |  e.- ltllaca elaaas—  al a ce  e eS e  t  ,  e
#
# an na bat 6 |  e.- ltllaca elaaas—  al a ce  e eS e  t  ,  e
#
# an na bat 6 |  e.- ltllaca elaaas—  al a ce  e eS e  t  ,  e
#
# an na bat 6 |  e.- ltllaca elaaas—  al a ce  e eS e  t  ,  e
#
# ee tsti“‘(“‘éléléCOS 0 SS 000d 0 a —et—<“i‘“i RR RR 00
#
# a EE SEE EE i, errr et ee EE ET LE ME a SS ee ee) ee ee ee eee oe eee ees ae tee > tA, eee ee ee Pe ee OR Se S®@ ee eee ee
#
# — =~ — Se ee ee eS bere" e-> e  o —  eS eS eT lee er ee ee ee
#
# SS ee ee, ———> SSS ee ee  —
#
# i ee ee ee a ee ee ee, eee ee. ee eee
#
# tS ee SS aS a rt a SS
#
#
#
# — OO L8 Eee EOE eee 0 0 el i I li I I ce UU UU UU NIN EE
#
# — OO L8 Eee EOE eee 0 0 el i I li I I ce UU UU UU NIN EE
#
# a rr re ee ee ee ll ee ee ttst—<‘sésOSCSs™s™*™*™*™*™SCSNR ec CR SS RR EN OE i i CCC ll I ee Cll Cll ee cc CCC CC I EE El —EeEOOOOOoOlca té®wltmeeDlClC
#
# a i I i a LE EI NN le em i a
#
# ~~ OL ON ae a ae a CCE on a NNN
#
# I een ee el eet et nee ee ee ee ee ee Ok Ed St a ee ae
#
# aa a a me eee eee ES SS eee | eee FE ee ee Re ee, eee, eee eee ee ee ee ee ees eee | ea OF Oe ee OO ee ee SE ee eS ee ee Ee
#
#
# el ES ete spe es A PRPs a SS ee, en dee hk RO OOO ee ee eee
#
# nee — ee en ee deg eet Se eS PR rg ee a a De me es > eee ae Oe en eee ee ee een ooo
#
# nee — ee en ee deg eet Se eS PR rg ee a a De me es > eee ae Oe en eee ee ee een ooo
#
#
#
#
# Done
# ---------------img_12.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# ATTA,
#
# OF ERAT),
#
# Complex
#
# Variables
#
# and
#
# Ap plications
#
# rh
#
# Soy
#
# James
#
# Ward
#
# Brown
#
# Ruel
#
# VA
#
# (*hurchill
#
# Done
# ---------------img_13.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# Joseph
#
# aN
#
# Gallian
#
# Sa
#
#
# COIN TEMPORARY
#
# ABS | RAC 1
#
# ALGEBRA
#
# Ninth
#
# Edition
#
# EEE OO OO EEE OOOO OOOO)
#
# ae
#
#
# Done
# ---------------img_14.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# aim)!
#
# ~
#
#
# =.
#
# oi
#
# DISCRETE
#
# MATHEMATICAL
#
# STRUCTURES
#
# ib aia)
#
# Edition
#
# KOLLMAN
#
# BUSBY
#
# ROSS
#
# Done
# ---------------img_15.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# >
#
#
# CENGAGE
#
# y € os aN
#
#
# se) alce
#
# Susanna
#
# S.
#
# mele
#
# Done
# ---------------img_16.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# yore
#
# Ay
#
# ROSS
#
# rlementary
#
# Analysis
#
# Tne
#
# Tneor
#
# y Of
#
# Calculus
#
#
# Secon
#
# d Edition
#
# Done
# ---------------img_17.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# eau
#
# edition
#
#
# Howard
#
# Anton
#
#
# ars
#
# RHorres
#
# APPLICATIONS
#
# VERSION
#
# WILEY
#
# Done
# ---------------img_18.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# a
#
#
# aerate
#
# Elementary
#
# et
#
# Linear
#
# al leleleyge:
#
# ,
#
# APPLICATIONS
#
# VERSION
#
#
#
# Done
# ---------------img_19.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0009.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0010.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0011.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0012.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0013.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0014.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0015.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0016.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0017.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0018.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0019.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0020.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0021.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0022.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0023.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0024.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0025.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0026.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0027.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0028.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0029.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0030.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0031.png
# O'REILLY
#
# Essantiqd|
#
# Matn
#
# for
#
# Lata
#
# Science
#
# Take
#
# Control]
#
# ot
#
# Your
#
# ata
#
# with
#
# Fundamenta!
#
# Calculus.
#
# | inear
#
# Algebra,
#
# Probability
#
# &
#
# Statistics
#
#
# ,
#
#
# 7
#
# eee
#
# a
#
# »
#
# Early
#
# Ralease
#
# er aes
#
# BSR eg48.
#
# maarien
#
# Jean
#
# Done
# ---------------img_20.png---------------
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0000.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0001.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0002.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0003.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0004.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0005.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0006.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0007.png
# /content/drive/MyDrive/LMS/E_12/images/tesseract_output/0008.png
# FINITE-DIMEN
#
# SIONAL
#
# _
#
# ‘ VECTOR
#
# SPACES
#
# en
#
# \f
#
# 4
#
#
# Done

# %%
tesseract_ocr_text_pos_list = []
tesseract_ocr_text_list = []
for i, (img_path, tesseract_ocr_result) in enumerate(tesseract_ocr_dict.items()):
  tesseract_ocr_text_list.append([i, tesseract_ocr_result['text_list']])
  tesseract_ocr_text_pos_list.append([i, list(tesseract_ocr_result['cropped_image_dict'].values())])

# %%
plt.figure(figsize=(15,50))

for i, image in enumerate(images):
    plt.subplot(10, 2, i+1)
    plt.title(f'index: {i}')
    
    text_pos_list = tesseract_ocr_text_pos_list[i][1]
    text_list = tesseract_ocr_text_list[i][1]
    text = ', '.join(text_list)

    for text_pos in text_pos_list:
        w = text_pos[2][0]-text_pos[0][0]
        h = text_pos[2][1]-text_pos[0][1]
        rect = patches.Rectangle(
            (text_pos[0]),
            w, h,
            linewidth=2,
            edgecolor='red',
            fill=False
        )
        plt.gca().add_patch(rect)

    img_bgr = cv2.imread(image)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    
    plt.imshow(img_rgb)

    plt.gca().get_xaxis().set_visible(False)
    plt.gca().get_yaxis().set_visible(False)

    plt.tight_layout()

plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### STEP3. 테스트 결과 정리

# %% [markdown]
# ##### keras-ocr 및 Tesseract로 테스트 진행한 결과
# <br>
#
#  * 문자 인식: keras-ocr 의 문자인식 숫자가 많고(detect), 더 정확한 문자인식률(recognize)을 나타냄
#
# |이미지|keras-ocr|Tesseract|
# |------|---|---|
# |image01|pearson','new','international','edition','algebra','michael','artin',<br> 'second','edition','pearson','always','learning'|PEARSON NEW INTERNAT. EDITION Algebra Vichael Artin Secon d <br> Edition AYS LEARWNIWN ce PEARSON|
# |image02|'first','course','a','in','differential','equations','modeling',<br> 'with','applications','11e'|i ae A First Cour ma DSS Ne FOUATIONS with Modeling Applications ‘a >. ae a s 3 i|
# |image03|'first','course','a','in','probability','tenth','edition'|A Hirst (Course in Probability . i r . 1 ,|
# |image04|'abstract','algebra','a','first','course','second','edition'|ABSTRACT 2S \   A First    af S ty ta eee|
# |image05|'andabpled','pure','sall','5','the','undergraduate','texts','5',<br> 'series','','advanced','calculus','intended','for','furnish','thie','back',<br> 'is','text',...|advanced ( aiculiu SS iS intended a a Text for Cott Aes. that furnish the hack- hon ...|
# |image06|'introduction','an','to','mathematics','abstract','robert','bond',<br> 'ja','william','keane','j'|No Introduction ce Abstract Mathematics ee) re Robert iF Bond TRI iF Keane|
# |image07|'texts','and','readings','trim','37','mathematics','in','e','l',<br> 'analysis','s','terence','tao','se','qa','300','t325','2000','val','hindustan',<br> 'ho','agency','book','l','lun','l'|& = Analysis I Terence Tao HINDUSTAN BOOK AGENCY|
# |image08|'edition','sixth','applied','combinatorics','alan','tucker'|APPLIED COMBINATORICS ALAN F\  TUC (44%|
# |image09|'calculus','edition','fourth','spivak','michael'|the CALCULUS Fourth Ree Michael Spivak|
# |image10|'james','stewart','calculus','eighth','edition','early','transcendentals'|AM JAMES STEWART eer sl oe Del 1ON [}————— Early Transcenadadentals|
# |image11|'calcises','made','easy','themeson','macmiltan'|el ES ete spe es A PRPs a SS ee, en dee hk RO OOO ee ee eee nee|
# |image12|'ninth','edition','complex','variables','applications','and',<br> 'zaxtiy','d','x','ward','brown','james','ruel','churchill','va'|ATTA, OF ERAT), Complex Variables and Ap plications rh Soy James<br> Ward Brown Ruel VA (*hurchill|
# |image13|'gallian','joseph','a','contemporary','abstract','algebra','ninth', 'edition'|Joseph aN Gallian Sa  COIN TEMPORARY ABS | RAC 1 ALGEBRA Ninth Edition EEE OO OO EEE OOOO OOOO) ae|
# |image14|'i','discrete','mathematical','structures','sixth','edition',<br> 'kolman','busby','ross'|oi DISCRETE MATHEMATICAL STRUCTURES ib aia) Edition KOLLMAN BUSBY ROSS|
# |image15|'cengage','discrete','mathematics','applications','with','fifth',<br> 'edition','susanna','s','epp'|CENGAGE y € os aN  se) alce Susanna S. Mele|
# |image16|'undergraduate','texts','mathematics','in','utm','kenneth','ross',<br> 'a','elementary','analysis','of','the','theory','calculus','edition','second',<br> 'e1', 'ed'|yore Ay ROSS rlementary Analysis Tne Tneor y Of Calculus  Secon d Edition|
# |image17|'11th','edition','nl','lnea','age','anton','chris','howard','rorres',<br> 'wiley','applications','version'|eau edition  Howard Anton  ars RHorres APPLICATIONS VERSION WILEY|
# |image18|'elementary','tenth','edition','linear','algebra','version', 'applications'|a  aerate Elementary et Linear al leleleyge: , APPLICATIONS VERSION|
# |image19|'oreilly','essential','math','science','data','for','of',<br> 'fundamental','take','control','your','with','data','calculus','probability',<br> 'linear','algebra','statistics','8','early','release','raw','s',<br> 'unedited','hadrien','jean'|O'REILLY Essantiqd| Matn for Lata Science Take Control] ot Your ata with Fundamenta! Calculus.<br> linear Algebra, Probability & Statistics  ,  7 eee a » Early Ralease er aes BSR eg48. maarien Jean|
# |image20|'finitedimensional','vector','spaces','second','edition','paul',<br> 'halmos','r'|FINITE-DIMEN SIONAL _ ‘ VECTOR SPACES en \f 4|
#
#  * 기울어진 글자 : 3번째 이미지에서 keras-ocr은 기울이게 인식하나, Tesseract는 기울어진 글자 인식하지 않음
#  * 세로글자 인식 여부: keras-ocr은 세로글씨 거의 인식하였으나, Tesseract는 일부는 인식하고 일부는 인식하지 않음
#  * 비문자의 인식 : Tesseract는 복잡한 배경 문양을 문자로 잘못 인식하는 경우가 많음

# %% [markdown]
# ### STEP4. 결과분석과 결론 제시
# <br>
#
# ##### 1. 서비스의 목적과 내용: <br>
# 본 서비스의 목적은 다양한 수학책의 표지로부터 책의 타이틀 및 저자 등 목록을 작성하기 위한 문자위치 확인 및 문자의 인식을 목적으로 함
#
# ##### 2. OCR모델이 서비스의 목적에 부합하는지의 기준: <br>
#   * 문자 Detect 수준: Detect한 문자의 갯수
#   * 문자 Recognize 수준: Detect한 문자의 올바른 인식
#   * 비문자 Detect 오류: 문자가 아닌 배경 문양등을 문자로 인식하는 오류수준
#   * 세로문자 인식: 가로 및 세로 형태의 문자 인식
#   * 삐뚤어진 문자 인식: 문자가 휘어진 경우 올바르게 인식하는지
#
# ##### 3. 기준에 따른 테스트 결과 및 모델 선정: <br>
#
# |평가기준|keras-ocr|Tesseract|
# |------|---|---|
# |1.문자 Detect수준|문자가 있는 부분 거의 detect하고 있음|배경색상등에 따라 일부 detect 못하는 문자 있음|
# |2.문자 Recognize 수준|한 단어가 나누어지기도 하나, 대부분 올바르게 인식|detect된 문자의 인식률이 상당히 떨어짐|
# |3.비문자 Detect오류|거의 없음|배경 도형 등을 문자로 잘못 인식하는 경우가 있음|
# |4.세로문자 인식|세로문자 인식함|세로문자 인식하는 경우 및 인식 못하는 경우 있음|
# |5.삐뚤어진 문자 인식|기울어진 문자 인식함|기울어진 문자 인식하지 못함|
# <br>
#
# ##### 평가기준에 따른 테스트 결과 keras-ocr 모델이 유리한 것으로 선정됨: <br>

# %% [markdown]
# ##### [ 회  고 ]
#  * 이미지 속의 문자인식을 위해서 우선 문자를 detect해 내야 한다는 점을 새로 인식하게 됨
#  * 내용이 복잡해질수록 이미 만들어진 API의 사용에 의존하게 되는 것 같음. 좋은 API를 비용없이 일반에 공유하는 문화가 확산되길 바래본다
#  * 의미의 전달이라는 측면에서 이미지 객체 detection보다 문자 detection이 실 생활에 더 유용할 수 있을 것 같다는 생각이 든다
#
# <br>
#
#  < reference >
#  * https://www.uipath.com/ko/blog/ using-artificial-intelligence-to-optimize-document-understanding
#  * https://brunch.co.kr/@kakao-it/318
